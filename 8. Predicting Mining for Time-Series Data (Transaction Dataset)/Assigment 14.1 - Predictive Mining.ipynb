# %%
import pandas as pd
data = pd.read_csv("transaction.csv") 
data
# Out:
#        InvoiceNo  StockCode  Qty      InvoiceDate  CustomerID  \
# 0         537626      22725  830  12/7/2010 14:57       12347
# 1         537626      22729  948  12/7/2010 14:57       12347
# 2         537626      22195  695  12/7/2010 14:57       12347
# 3         542237      22725  636  1/26/2011 14:30       12347
# 4         542237      22729  536  1/26/2011 14:30       12347
# ...          ...        ...  ...              ...         ...
# 10541     543911      21700  455  2/14/2011 12:46       17829
# 10542     543911      22111  578  2/14/2011 12:46       17829
# 10543     543911      22112  163  2/14/2011 12:46       17829
# 10544     564428      23296  545  8/25/2011 11:27       17844
# 10545     564428      23294  643  8/25/2011 11:27       17844
#
#                     Country
# 0                   Iceland
# 1                   Iceland
# 2                   Iceland
# 3                   Iceland
# 4                   Iceland
# ...                     ...
# ...

# %%
new_data = data[['Qty', 'InvoiceDate', 'Country']]
new_data['Month'] = pd.DatetimeIndex(new_data['InvoiceDate']).month
new_data['Year'] = pd.DatetimeIndex(new_data['InvoiceDate']).year
new_data = new_data.loc[(new_data['Country'] == 'Germany') & (new_data['Year'] == 2011)]
new_data = new_data.drop(columns=['InvoiceDate'])
new_data
# Out:
# C:\Users\owner\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\owner\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Qty  Country  Month  Year
# 1185  628  Germany      5  2011
# 1186  981  Germany      5  2011
# 1187  212  Germany      5  2011
# 1188  910  Germany      5  2011
# ...

# %%
new_dataMonth = new_data['Month'].value_counts()
new_dataMonth = new_dataMonth.sort_index()
new_dataMonth
# Out:
# 1     201
# 2      73
# 3     144
# 4     120
# 5     195
# 6     154
# 7     192
# 8     225
# 9     204
# 10    300
# 11    271
# 12     69
# Name: Month, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.plot(new_dataMonth)
plt.show()

# %% [markdown]
# # Linear Regression

# %%
X = 0
Y = 0
XX = 0
XY = 0
print("X\t", "Y\t","XX\t", "XY")
for i in range (1,12+1):
    X = X + i
    Y = Y + new_dataMonth[i]
    XX = XX + i*i
    XY = XY + i*new_dataMonth[i]
    print(X, "\t", Y, "\t", XX, "\t",  XY)
print('='*50)

n=12
a = ((Y*XX) - (X*XY))/((n*XX) - X*X)
b = ((n)*(XY) - (X*Y))/((n*XX) - X*X)
print("a:", a)
print("b:", b)
print("==> Y =",a,"+",b,"*X")

# Predicted Quantity January 2012
Out = a + b*13
print('Predicted January 2012 = ', Out)
# Out:
# X	 Y	 XX	 XY
# 1 	 201 	 1 	 201
# 3 	 274 	 5 	 347
# 6 	 418 	 14 	 779
# 10 	 538 	 30 	 1259
# 15 	 733 	 55 	 2234
# 21 	 887 	 91 	 3158
# 28 	 1079 	 140 	 4502
# 36 	 1304 	 204 	 6302
# 45 	 1508 	 285 	 8138
# 55 	 1808 	 385 	 11138
# 66 	 2079 	 506 	 14119
# 78 	 2148 	 650 	 14947
# ...
# a: 134.22727272727272
# b: 6.888111888111888
# ==> Y = 134.22727272727272 + 6.888111888111888 *X
# Predicted January 2012 =  223.77272727272725

# %% [markdown]
# # Predict

# %%
OutV2 = []
for i in range (4,12+1):
    OutV2 = 
    print(i)
# Out:
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# 12
